# %%
import torch
import torch.nn.functional as F
import matplotlib.pyplot as plt

from torch import nn
from torch import Tensor
from PIL import Image
from torchvision.transforms import Compose, Resize, ToTensor
from einops import rearrange, reduce, repeat
from einops.layers.torch import Rearrange, Reduce
from torchsummary import summary

# %%
class PatchEmbedding(nn.Module):
    def __init__(self, in_channels: int = 3, patch_size: int = 16, emb_size: int = 768, img_size: int = 224):
        self.patch_size = patch_size
        super().__init__()
        self.projection = nn.Sequential(
            # using a conv layer instead of a linear one -> performance gains
            nn.Conv2d(in_channels, emb_size, kernel_size=patch_size, stride=patch_size),
            Rearrange('b e (h) (w) -> b (h w) e'),
        )
        self.cls_token = nn.Parameter(torch.randn(1,1, emb_size))
        self.positions = nn.Parameter(torch.randn((img_size // patch_size) **2 + 1, emb_size))
        
    def forward(self, x: Tensor) -> Tensor:
        b, _, _, _ = x.shape
        x = self.projection(x)
        cls_tokens = repeat(self.cls_token, '() n e -> b n e', b=b)
        # prepend the cls token to the input
        x = torch.cat([cls_tokens, x], dim=1)
        # add position embedding
        x += self.positions

        return x

# %%
class MultiHeadAttention(nn.Module):
    def __init__(self, emb_size: int = 768, num_heads: int = 8, dropout: float = 0):
        super().__init__()
        self.emb_size = emb_size
        self.num_heads = num_heads
        # fuse the queries, keys and values in one matrix
        self.qkv = nn.Linear(emb_size, emb_size * 3)
        self.att_drop = nn.Dropout(dropout)
        self.projection = nn.Linear(emb_size, emb_size)
        
    def forward(self, x : Tensor, mask: Tensor = None) -> Tensor:
        # split keys, queries and values in num_heads
        qkv = rearrange(self.qkv(x), "b n (h d qkv) -> (qkv) b h n d", h=self.num_heads, qkv=3)
        queries, keys, values = qkv[0], qkv[1], qkv[2]
        # sum up over the last axis
        energy = torch.einsum('bhqd, bhkd -> bhqk', queries, keys) # batch, num_heads, query_len, key_len
        if mask is not None:
            fill_value = torch.finfo(torch.float32).min
            energy.mask_fill(~mask, fill_value)
            
        scaling = self.emb_size ** (1/2)
        att = F.softmax(energy, dim=-1) / scaling
        att = self.att_drop(att)
        # sum up over the third axis
        out = torch.einsum('bhal, bhlv -> bhav ', att, values)
        out = rearrange(out, "b h n d -> b n (h d)")
        out = self.projection(out)
        return out

# %%
class ResidualAdd(nn.Module):
    def __init__(self, fn):
        super().__init__()
        self.fn = fn
        
    def forward(self, x, **kwargs):
        res = x
        x = self.fn(x, **kwargs)
        x += res
        return x

# %%
class FeedForwardBlock(nn.Sequential):
    def __init__(self, emb_size: int, expansion: int = 4, drop_p: float = 0.):
        super().__init__(
            nn.Linear(emb_size, expansion * emb_size),
            nn.GELU(),
            nn.Dropout(drop_p),
            nn.Linear(expansion * emb_size, emb_size),
        )

# %%
class TransformerEncoderBlock(nn.Sequential):
    def __init__(self,
                 emb_size: int = 768,
                 drop_p: float = 0.,
                 forward_expansion: int = 4,
                 forward_drop_p: float = 0.,
                 ** kwargs):
        super().__init__(
            ResidualAdd(nn.Sequential(
                nn.LayerNorm(emb_size),
                MultiHeadAttention(emb_size, **kwargs),
                nn.Dropout(drop_p)
            )),
            ResidualAdd(nn.Sequential(
                nn.LayerNorm(emb_size),
                FeedForwardBlock(
                    emb_size, expansion=forward_expansion, drop_p=forward_drop_p),
                nn.Dropout(drop_p)
            )
            ))

# %%
class TransformerEncoder(nn.Sequential):
    def __init__(self, depth: int = 12, **kwargs):
        super().__init__(*[TransformerEncoderBlock(**kwargs) for _ in range(depth)])

# %%
class ClassificationHead(nn.Sequential):
    def __init__(self, emb_size: int = 768, n_classes: int = 1000):
        super().__init__(
            Reduce('b n e -> b e', reduction='mean'),
            nn.LayerNorm(emb_size), 
            nn.Linear(emb_size, n_classes))

# %%
class ViT(nn.Sequential):
    def __init__(self,     
                in_channels: int = 3,
                patch_size: int = 16,
                emb_size: int = 768,
                img_size: int = 224,
                depth: int = 12,
                n_classes: int = 1000,
                **kwargs):
        super().__init__(
            PatchEmbedding(in_channels, patch_size, emb_size, img_size),
            TransformerEncoder(depth, emb_size=emb_size, **kwargs),
            ClassificationHead(emb_size, n_classes)
        )
        
summary(ViT(), (3, 224, 224), device='cpu')
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1          [-1, 768, 14, 14]         590,592
#          Rearrange-2             [-1, 196, 768]               0
#     PatchEmbedding-3             [-1, 197, 768]               0
#          LayerNorm-4             [-1, 197, 768]           1,536
#             Linear-5            [-1, 197, 2304]       1,771,776
#            Dropout-6          [-1, 8, 197, 197]               0
#             Linear-7             [-1, 197, 768]         590,592
# MultiHeadAttention-8             [-1, 197, 768]               0
#            Dropout-9             [-1, 197, 768]               0
#       ResidualAdd-10             [-1, 197, 768]               0
#         LayerNorm-11             [-1, 197, 768]           1,536
#            Linear-12            [-1, 197, 3072]       2,362,368
#              GELU-13            [-1, 197, 3072]               0
#           Dropout-14            [-1, 197, 3072]               0
#            Linear-15             [-1, 197, 768]       2,360,064
#           Dropout-16             [-1, 197, 768]               0
#       ResidualAdd-17             [-1, 197, 768]               0
#         LayerNorm-18             [-1, 197, 768]           1,536
#            Linear-19            [-1, 197, 2304]       1,771,776
#           Dropout-20          [-1, 8, 197, 197]               0
#            Linear-21             [-1, 197, 768]         590,592
# MultiHeadAttention-22             [-1, 197, 768]               0
#           Dropout-23             [-1, 197, 768]               0
#       ResidualAdd-24             [-1, 197, 768]               0
#         LayerNorm-25             [-1, 197, 768]           1,536
#            Linear-26            [-1, 197, 3072]       2,362,368
#              GELU-27            [-1, 197, 3072]               0
#           Dropout-28            [-1, 197, 3072]               0
#            Linear-29             [-1, 197, 768]       2,360,064
#           Dropout-30             [-1, 197, 768]               0
#       ResidualAdd-31             [-1, 197, 768]               0
#         LayerNorm-32             [-1, 197, 768]           1,536
#            Linear-33            [-1, 197, 2304]       1,771,776
#           Dropout-34          [-1, 8, 197, 197]               0
#            Linear-35             [-1, 197, 768]         590,592
# MultiHeadAttention-36             [-1, 197, 768]               0
#           Dropout-37             [-1, 197, 768]               0
#       ResidualAdd-38             [-1, 197, 768]               0
#         LayerNorm-39             [-1, 197, 768]           1,536
#            Linear-40            [-1, 197, 3072]       2,362,368
#              GELU-41            [-1, 197, 3072]               0
#           Dropout-42            [-1, 197, 3072]               0
#            Linear-43             [-1, 197, 768]       2,360,064
#           Dropout-44             [-1, 197, 768]               0
#       ResidualAdd-45             [-1, 197, 768]               0
#         LayerNorm-46             [-1, 197, 768]           1,536
#            Linear-47            [-1, 197, 2304]       1,771,776
#           Dropout-48          [-1, 8, 197, 197]               0
#            Linear-49             [-1, 197, 768]         590,592
# MultiHeadAttention-50             [-1, 197, 768]               0
#           Dropout-51             [-1, 197, 768]               0
#       ResidualAdd-52             [-1, 197, 768]               0
#         LayerNorm-53             [-1, 197, 768]           1,536
#            Linear-54            [-1, 197, 3072]       2,362,368
#              GELU-55            [-1, 197, 3072]               0
#           Dropout-56            [-1, 197, 3072]               0
#            Linear-57             [-1, 197, 768]       2,360,064
#           Dropout-58             [-1, 197, 768]               0
#       ResidualAdd-59             [-1, 197, 768]               0
#         LayerNorm-60             [-1, 197, 768]           1,536
#            Linear-61            [-1, 197, 2304]       1,771,776
#           Dropout-62          [-1, 8, 197, 197]               0
#            Linear-63             [-1, 197, 768]         590,592
# MultiHeadAttention-64             [-1, 197, 768]               0
#           Dropout-65             [-1, 197, 768]               0
#       ResidualAdd-66             [-1, 197, 768]               0
#         LayerNorm-67             [-1, 197, 768]           1,536
#            Linear-68            [-1, 197, 3072]       2,362,368
#              GELU-69            [-1, 197, 3072]               0
#           Dropout-70            [-1, 197, 3072]               0
#            Linear-71             [-1, 197, 768]       2,360,064
#           Dropout-72             [-1, 197, 768]               0
#       ResidualAdd-73             [-1, 197, 768]               0
#         LayerNorm-74             [-1, 197, 768]           1,536
#            Linear-75            [-1, 197, 2304]       1,771,776
#           Dropout-76          [-1, 8, 197, 197]               0
#            Linear-77             [-1, 197, 768]         590,592
# MultiHeadAttention-78             [-1, 197, 768]               0
#           Dropout-79             [-1, 197, 768]               0
#       ResidualAdd-80             [-1, 197, 768]               0
#         LayerNorm-81             [-1, 197, 768]           1,536
#            Linear-82            [-1, 197, 3072]       2,362,368
#              GELU-83            [-1, 197, 3072]               0
#           Dropout-84            [-1, 197, 3072]               0
#            Linear-85             [-1, 197, 768]       2,360,064
#           Dropout-86             [-1, 197, 768]               0
#       ResidualAdd-87             [-1, 197, 768]               0
#         LayerNorm-88             [-1, 197, 768]           1,536
#            Linear-89            [-1, 197, 2304]       1,771,776
#           Dropout-90          [-1, 8, 197, 197]               0
#            Linear-91             [-1, 197, 768]         590,592
# MultiHeadAttention-92             [-1, 197, 768]               0
#           Dropout-93             [-1, 197, 768]               0
#       ResidualAdd-94             [-1, 197, 768]               0
#         LayerNorm-95             [-1, 197, 768]           1,536
#            Linear-96            [-1, 197, 3072]       2,362,368
#              GELU-97            [-1, 197, 3072]               0
#           Dropout-98            [-1, 197, 3072]               0
#            Linear-99             [-1, 197, 768]       2,360,064
#          Dropout-100             [-1, 197, 768]               0
#      ResidualAdd-101             [-1, 197, 768]               0
#        LayerNorm-102             [-1, 197, 768]           1,536
#           Linear-103            [-1, 197, 2304]       1,771,776
#          Dropout-104          [-1, 8, 197, 197]               0
#           Linear-105             [-1, 197, 768]         590,592
# MultiHeadAttention-106             [-1, 197, 768]               0
#          Dropout-107             [-1, 197, 768]               0
#      ResidualAdd-108             [-1, 197, 768]               0
#        LayerNorm-109             [-1, 197, 768]           1,536
#           Linear-110            [-1, 197, 3072]       2,362,368
#             GELU-111            [-1, 197, 3072]               0
#          Dropout-112            [-1, 197, 3072]               0
#           Linear-113             [-1, 197, 768]       2,360,064
#          Dropout-114             [-1, 197, 768]               0
#      ResidualAdd-115             [-1, 197, 768]               0
#        LayerNorm-116             [-1, 197, 768]           1,536
#           Linear-117            [-1, 197, 2304]       1,771,776
#          Dropout-118          [-1, 8, 197, 197]               0
#           Linear-119             [-1, 197, 768]         590,592
# MultiHeadAttention-120             [-1, 197, 768]               0
#          Dropout-121             [-1, 197, 768]               0
#      ResidualAdd-122             [-1, 197, 768]               0
#        LayerNorm-123             [-1, 197, 768]           1,536
#           Linear-124            [-1, 197, 3072]       2,362,368
#             GELU-125            [-1, 197, 3072]               0
#          Dropout-126            [-1, 197, 3072]               0
#           Linear-127             [-1, 197, 768]       2,360,064
#          Dropout-128             [-1, 197, 768]               0
#      ResidualAdd-129             [-1, 197, 768]               0
#        LayerNorm-130             [-1, 197, 768]           1,536
#           Linear-131            [-1, 197, 2304]       1,771,776
#          Dropout-132          [-1, 8, 197, 197]               0
#           Linear-133             [-1, 197, 768]         590,592
# MultiHeadAttention-134             [-1, 197, 768]               0
#          Dropout-135             [-1, 197, 768]               0
#      ResidualAdd-136             [-1, 197, 768]               0
#        LayerNorm-137             [-1, 197, 768]           1,536
#           Linear-138            [-1, 197, 3072]       2,362,368
#             GELU-139            [-1, 197, 3072]               0
#          Dropout-140            [-1, 197, 3072]               0
#           Linear-141             [-1, 197, 768]       2,360,064
#          Dropout-142             [-1, 197, 768]               0
#      ResidualAdd-143             [-1, 197, 768]               0
#        LayerNorm-144             [-1, 197, 768]           1,536
#           Linear-145            [-1, 197, 2304]       1,771,776
#          Dropout-146          [-1, 8, 197, 197]               0
#           Linear-147             [-1, 197, 768]         590,592
# MultiHeadAttention-148             [-1, 197, 768]               0
#          Dropout-149             [-1, 197, 768]               0
#      ResidualAdd-150             [-1, 197, 768]               0
#        LayerNorm-151             [-1, 197, 768]           1,536
#           Linear-152            [-1, 197, 3072]       2,362,368
#             GELU-153            [-1, 197, 3072]               0
#          Dropout-154            [-1, 197, 3072]               0
#           Linear-155             [-1, 197, 768]       2,360,064
#          Dropout-156             [-1, 197, 768]               0
#      ResidualAdd-157             [-1, 197, 768]               0
#        LayerNorm-158             [-1, 197, 768]           1,536
#           Linear-159            [-1, 197, 2304]       1,771,776
#          Dropout-160          [-1, 8, 197, 197]               0
#           Linear-161             [-1, 197, 768]         590,592
# MultiHeadAttention-162             [-1, 197, 768]               0
#          Dropout-163             [-1, 197, 768]               0
#      ResidualAdd-164             [-1, 197, 768]               0
#        LayerNorm-165             [-1, 197, 768]           1,536
#           Linear-166            [-1, 197, 3072]       2,362,368
#             GELU-167            [-1, 197, 3072]               0
#          Dropout-168            [-1, 197, 3072]               0
#           Linear-169             [-1, 197, 768]       2,360,064
#          Dropout-170             [-1, 197, 768]               0
#      ResidualAdd-171             [-1, 197, 768]               0
#           Reduce-172                  [-1, 768]               0
#        LayerNorm-173                  [-1, 768]           1,536
#           Linear-174                 [-1, 1000]         769,000
# ================================================================
# Total params: 86,415,592
# Trainable params: 86,415,592
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.57
# Forward/backward pass size (MB): 364.33
# Params size (MB): 329.65
# Estimated Total Size (MB): 694.56
# ----------------------------------------------------------------

# %%
# dataset and transformation
from torchvision import datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from torchvision import models
import os

# display images
from torchvision import utils
import matplotlib.pyplot as plt
# %matplotlib inline

# utils
import numpy as np
from torchsummary import summary
import time
import copy
# specify path to data
path2data = './data'

# if not exists the path, make the directory
if not os.path.exists(path2data):
    os.mkdir(path2data)

# load dataset
train_ds = datasets.STL10(path2data, split='train', download=True, transform=transforms.ToTensor())
val_ds = datasets.STL10(path2data, split='test', download=True, transform=transforms.ToTensor())
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
# define transformation
transformation = transforms.Compose([
                    transforms.ToTensor(),
                    transforms.Resize(224)
])

# apply transformation to dataset
train_ds.transform = transformation
val_ds.transform = transformation

# make dataloade
train_dl = DataLoader(train_ds, batch_size=32, shuffle=True)
val_dl = DataLoader(val_ds, batch_size=32, shuffle=True)

# %%
model = ViT(n_classes=10)
model.to('cuda')
# Out:
# ViT(
#   (0): PatchEmbedding(
#     (projection): Sequential(
#       (0): Conv2d(3, 768, kernel_size=(16, 16), stride=(16, 16))
#       (1): Rearrange('b e (h) (w) -> b (h w) e')
#     )
#   )
#   (1): TransformerEncoder(
#     (0): TransformerEncoderBlock(
#       (0): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): MultiHeadAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (att_drop): Dropout(p=0, inplace=False)
#             (projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): FeedForwardBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU()
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (1): TransformerEncoderBlock(
#       (0): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): MultiHeadAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (att_drop): Dropout(p=0, inplace=False)
#             (projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): FeedForwardBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU()
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (2): TransformerEncoderBlock(
#       (0): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): MultiHeadAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (att_drop): Dropout(p=0, inplace=False)
#             (projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): FeedForwardBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU()
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (3): TransformerEncoderBlock(
#       (0): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): MultiHeadAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (att_drop): Dropout(p=0, inplace=False)
#             (projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): FeedForwardBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU()
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (4): TransformerEncoderBlock(
#       (0): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): MultiHeadAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (att_drop): Dropout(p=0, inplace=False)
#             (projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): FeedForwardBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU()
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (5): TransformerEncoderBlock(
#       (0): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): MultiHeadAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (att_drop): Dropout(p=0, inplace=False)
#             (projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): FeedForwardBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU()
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (6): TransformerEncoderBlock(
#       (0): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): MultiHeadAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (att_drop): Dropout(p=0, inplace=False)
#             (projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): FeedForwardBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU()
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (7): TransformerEncoderBlock(
#       (0): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): MultiHeadAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (att_drop): Dropout(p=0, inplace=False)
#             (projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): FeedForwardBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU()
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (8): TransformerEncoderBlock(
#       (0): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): MultiHeadAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (att_drop): Dropout(p=0, inplace=False)
#             (projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): FeedForwardBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU()
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (9): TransformerEncoderBlock(
#       (0): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): MultiHeadAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (att_drop): Dropout(p=0, inplace=False)
#             (projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): FeedForwardBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU()
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (10): TransformerEncoderBlock(
#       (0): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): MultiHeadAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (att_drop): Dropout(p=0, inplace=False)
#             (projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): FeedForwardBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU()
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#     (11): TransformerEncoderBlock(
#       (0): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): MultiHeadAttention(
#             (qkv): Linear(in_features=768, out_features=2304, bias=True)
#             (att_drop): Dropout(p=0, inplace=False)
#             (projection): Linear(in_features=768, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#       (1): ResidualAdd(
#         (fn): Sequential(
#           (0): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#           (1): FeedForwardBlock(
#             (0): Linear(in_features=768, out_features=3072, bias=True)
#             (1): GELU()
#             (2): Dropout(p=0.0, inplace=False)
#             (3): Linear(in_features=3072, out_features=768, bias=True)
#           )
#           (2): Dropout(p=0.0, inplace=False)
#         )
#       )
#     )
#   )
#   (2): ClassificationHead(
#     (0): Reduce('b n e -> b e', 'mean')
#     (1): LayerNorm((768,), eps=1e-05, elementwise_affine=True)
#     (2): Linear(in_features=768, out_features=10, bias=True)
#   )
# )

# %%
from torch import optim

# %%
# define loss function, optimizer, lr_scheduler
loss_func = nn.CrossEntropyLoss(reduction='sum')
opt = optim.Adam(model.parameters(), lr=0.01)

from torch.optim.lr_scheduler import ReduceLROnPlateau
lr_scheduler = ReduceLROnPlateau(opt, mode='min', factor=0.1, patience=10)


# get current lr
def get_lr(opt):
    for param_group in opt.param_groups:
        return param_group['lr']


# calculate the metric per mini-batch
def metric_batch(output, target):
    pred = output.argmax(1, keepdim=True)
    corrects = pred.eq(target.view_as(pred)).sum().item()
    return corrects


# calculate the loss per mini-batch
def loss_batch(loss_func, output, target, opt=None):
    loss_b = loss_func(output, target)
    metric_b = metric_batch(output, target)

    if opt is not None:
        opt.zero_grad()
        loss_b.backward()
        opt.step()
    
    return loss_b.item(), metric_b


# calculate the loss per epochs
def loss_epoch(model, loss_func, dataset_dl, sanity_check=False, opt=None):
    running_loss = 0.0
    running_metric = 0.0
    len_data = len(dataset_dl.dataset)

    for xb, yb in dataset_dl:
        xb = xb.to(device)
        yb = yb.to(device)
        output = model(xb)

        loss_b, metric_b = loss_batch(loss_func, output, yb, opt)

        running_loss += loss_b
        
        if metric_b is not None:
            running_metric += metric_b

        if sanity_check is True:
            break

    loss = running_loss / len_data
    metric = running_metric / len_data
    return loss, metric


# function to start training
def train_val(model, params):
    num_epochs=params['num_epochs']
    loss_func=params['loss_func']
    opt=params['optimizer']
    train_dl=params['train_dl']
    val_dl=params['val_dl']
    sanity_check=params['sanity_check']
    lr_scheduler=params['lr_scheduler']
    path2weights=params['path2weights']

    loss_history = {'train': [], 'val': []}
    metric_history = {'train': [], 'val': []}

    best_loss = float('inf')
    best_model_wts = copy.deepcopy(model.state_dict())
    start_time = time.time()

    for epoch in range(num_epochs):
        current_lr = get_lr(opt)
        print('Epoch {}/{}, current lr= {}'.format(epoch, num_epochs-1, current_lr))

        model.train()
        train_loss, train_metric = loss_epoch(model, loss_func, train_dl, sanity_check, opt)
        loss_history['train'].append(train_loss)
        metric_history['train'].append(train_metric)

        model.eval()
        with torch.no_grad():
            val_loss, val_metric = loss_epoch(model, loss_func, val_dl, sanity_check)
        loss_history['val'].append(val_loss)
        metric_history['val'].append(val_metric)

        if val_loss < best_loss:
            best_loss = val_loss
            best_model_wts = copy.deepcopy(model.state_dict())
            torch.save(model.state_dict(), path2weights)
            print('Copied best model weights!')

        lr_scheduler.step(val_loss)
        if current_lr != get_lr(opt):
            print('Loading best model weights!')
            model.load_state_dict(best_model_wts)

        print('train loss: %.6f, val loss: %.6f, accuracy: %.2f, time: %.4f min' %(train_loss, val_loss, 100*val_metric, (time.time()-start_time)/60))
        print('-'*10)

    model.load_state_dict(best_model_wts)
    return model, loss_history, metric_history

# %%
device='cuda'

# %%
# define the training parameters
params_train = {
    'num_epochs':100,
    'optimizer':opt,
    'loss_func':loss_func,
    'train_dl':train_dl,
    'val_dl':val_dl,
    'sanity_check':False,
    'lr_scheduler':lr_scheduler,
    'path2weights':'./models/weights.pt',
}

# check the directory to save weights.pt
def createFolder(directory):
    try:
        if not os.path.exists(directory):
            os.makedirs(directory)
    except OSerror:
        print('Error')
createFolder('./models')

# %%
model, loss_hist, metric_hist = train_val(model, params_train)
# Out:
# Epoch 0/99, current lr= 0.01
# Copied best model weights!
# train loss: 3.060160, val loss: 2.391015, accuracy: 15.56, time: 1.6620 min
# ----------
# Epoch 1/99, current lr= 0.01
# Copied best model weights!
# train loss: 2.260798, val loss: 2.101565, accuracy: 16.60, time: 3.3348 min
# ----------
# Epoch 2/99, current lr= 0.01
# train loss: 2.061987, val loss: 2.118208, accuracy: 18.01, time: 4.9726 min
# ----------
# Epoch 3/99, current lr= 0.01
# Copied best model weights!
# train loss: 2.040166, val loss: 2.015960, accuracy: 20.60, time: 6.6432 min
# ----------
# Epoch 4/99, current lr= 0.01
# train loss: 2.034011, val loss: 2.070697, accuracy: 18.40, time: 8.2864 min
# ----------
# Epoch 5/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.995636, val loss: 2.009832, accuracy: 20.03, time: 9.9636 min
# ----------
# Epoch 6/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.982894, val loss: 1.971139, accuracy: 23.34, time: 11.6363 min
# ----------
# Epoch 7/99, current lr= 0.01
# Copied best model weights!
# train loss: 1.943931, val loss: 1.944502, accuracy: 24.12, time: 13.3021 min
# ----------
# Epoch 8/99, current lr= 0.01
# Copied best model weights!
# train loss: 1
99, current lr= 0.001
# Copied best model weights!
# train loss: 1.706403, val loss: 1.692238, accuracy: 34.51, time: 97.6146 min
# ----------
# Epoch 59/99, current lr= 0.001
# train loss: 1.697865, val loss: 1.708682, accuracy: 34.24, time: 99.2581 min
# ----------
# Epoch 60/99, current lr= 0.001
# train loss: 1.713104, val loss: 1.717379, accuracy: 33.27, time: 100.9083 min
# ----------
# Epoch 61/99, current lr= 0.001
# train loss: 1.705824, val loss: 1.701836, accuracy: 34.64, time: 102.5608 min
# ----------
# Epoch 62/99, current lr= 0.001
# train loss: 1.753482, val loss: 1.753498, accuracy: 31.50, time: 104.2042 min
# ----------
# Epoch 63/99, current lr= 0.001
# train loss: 1.726724, val loss: 1.711609, accuracy: 34.00, time: 105.8539 min
# ----------
# Epoch 64/99, current lr= 0.001
# train loss: 1.699887, val loss: 1.699883, accuracy: 34.81, time: 107.5048 min
# ----------
# Epoch 65/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.687775, val loss: 1.689389, accuracy: 34.85, time: 109.1845 min
# ----------
# Epoch 66/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.675290, val loss: 1.680719, accuracy: 35.14, time: 110.8715 min
# ----------
# Epoch 67/99, current lr= 0.001
# train loss: 1.671889, val loss: 1.689282, accuracy: 34.88, time: 112.5203 min
# ----------
# Epoch 68/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.670599, val loss: 1.668643, accuracy: 36.04, time: 114.2019 min
# ----------
# Epoch 69/99, current lr= 0.001
# train loss: 1.659626, val loss: 1.705420, accuracy: 35.26, time: 115.8568 min
# ----------
# Epoch 70/99, current lr= 0.001
# train loss: 1.676717, val loss: 1.688491, accuracy: 34.34, time: 117.5108 min
# ----------
# Epoch 71/99, current lr= 0.001
# train loss: 1.657710, val loss: 1.778808, accuracy: 32.67, time: 119.1590 min
# ----------
# Epoch 72/99, current lr= 0.001
# train loss: 1.692380, val loss: 1.868210, accuracy: 31.49, time: 120.8066 min
# ----------
# Epoch 73/99, current lr= 0.001
# train loss: 1.752751, val loss: 1.701334, accuracy: 34.90, time: 122.4545 min
# ----------
# Epoch 74/99, current lr= 0.001
# train loss: 1.678969, val loss: 1.676024, accuracy: 35.35, time: 124.1053 min
# ----------
# Epoch 75/99, current lr= 0.001
# train loss: 1.674294, val loss: 1.677886, accuracy: 34.99, time: 125.7501 min
# ----------
# Epoch 76/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.655700, val loss: 1.666050, accuracy: 36.40, time: 127.4255 min
# ----------
# Epoch 77/99, current lr= 0.001
# train loss: 1.648616, val loss: 1.684341, accuracy: 34.73, time: 129.0752 min
# ----------
# Epoch 78/99, current lr= 0.001
# Copied best model weights!
# train loss: 1.642878, val loss: 1.661170, accuracy: 36.33, time: 130.7525 min
# ----------
# Epoch 79/99, current lr= 0.001
# train loss: 1.638662, val loss: 1.670265, accuracy: 35.99, time: 132.4041 min
# ----------
# Epoch 80/99, current lr= 0.001
# train loss: 1.640009, val loss: 1.665187, accuracy: 36.38, time: 134.0511 min
# ----------
# Epoch 81/99, current lr= 0.001
# train loss: 1.642105, val loss: 1.668478, accuracy: 35.77, time: 135.6997 min
# ----------
# Epoch 82/99, current lr= 0.001
# train loss: 1.642169, val loss: 1.666171, accuracy: 35.94, time: 137.3468 min
# ----------
# Epoch 83/99, current lr= 0.001
# train loss: 1.634530, val loss: 1.678506, accuracy: 34.66, time: 138.9923 min
# ----------
# Epoch 84/99, current lr= 0.001
# train loss: 1.659815, val loss: 1.762665, accuracy: 33.01, time: 140.6481 min
# ----------
# Epoch 85/99, current lr= 0.001
# train loss: 1.666269, val loss: 1.664822, accuracy: 36.10, time: 142.2943 min
# ----------
# Epoch 86/99, current lr= 0.001
# train loss: 1.649100, val loss: 1.662847, accuracy: 36.23, time: 143.9409 min
# ----------
# Epoch 87/99, current lr= 0.001
# train loss: 1.632457, val loss: 1.673297, accuracy: 35.39, time: 145.5901 min
# ----------
# Epoch 88/99, current lr= 0.001
# train loss: 1.686758, val loss: 1.802667, accuracy: 30.16, time: 147.2325 min
# ----------
# Epoch 89/99, current lr= 0.001
# Loading best model weights!
# train loss: 1.773178, val loss: 1.767096, accuracy: 31.74, time: 148.8755 min
# ----------
# Epoch 90/99, current lr= 0.0001
# Copied best model weights!
# train loss: 1.618817, val loss: 1.651956, accuracy: 37.14, time: 150.5590 min
# ----------
# Epoch 91/99, current lr= 0.0001
# train loss: 1.613076, val loss: 1.653555, accuracy: 36.95, time: 152.2072 min
# ----------
# Epoch 92/99, current lr= 0.0001
# Copied best model weights!
# train loss: 1.611285, val loss: 1.649901, accuracy: 37.08, time: 153.8897 min
# ----------
# Epoch 93/99, current lr= 0.0001
# Copied best model weights!
# train loss: 1.609696, val loss: 1.648859, accuracy: 37.11, time: 155.5744 min
# ----------
# Epoch 94/99, current lr= 0.0001
# Copied best model weights!
# train loss: 1.607480, val loss: 1.648162, accuracy: 37.31, time: 157.2607 min
# ----------
# Epoch 95/99, current lr= 0.0001
# Copied best model weights!
# train loss: 1.607626, val loss: 1.646740, accuracy: 37.11, time: 158.9401 min
# ----------
# Epoch 96/99, current lr= 0.0001
# train loss: 1.607907, val loss: 1.648410, accuracy: 37.05, time: 160.5906 min
# ----------
# Epoch 97/99, current lr= 0.0001
# Copied best model weights!
# train loss: 1.606638, val loss: 1.646004, accuracy: 37.33, time: 162.2679 min
# ----------
# Epoch 98/99, current lr= 0.0001
# Copied best model weights!
# train loss: 1.605124, val loss: 1.645829, accuracy: 37.28, time: 163.9486 min
# ----------
# Epoch 99/99, current lr= 0.0001
# train loss: 1.605093, val loss: 1.647268, accuracy: 37.21, time: 165.5954 min
# ----------

# %%
num_epochs = params_train['num_epochs']

# Plot train-val loss
plt.title('Train-Val Loss')
plt.plot(range(1, num_epochs+1), loss_hist['train'], label='train')
plt.plot(range(1, num_epochs+1), loss_hist['val'], label='val')
plt.ylabel('Loss')
plt.xlabel('Training Epochs')
plt.legend()
plt.tight_layout()
plt.savefig('ViT_loss.jpg', bbox_inches='tight')
plt.show()



# plot train-val accuracy
plt.title('Train-Val Accuracy')
plt.plot(range(1, num_epochs+1), metric_hist['train'], label='train')
plt.plot(range(1, num_epochs+1), metric_hist['val'], label='val')
plt.ylabel('Accuracy')
plt.xlabel('Training Epochs')
plt.legend()
plt.tight_layout()
plt.savefig('ViT_accuracy.jpg', bbox_inches='tight')
plt.show()
