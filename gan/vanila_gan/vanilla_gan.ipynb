# %%
import torch
import torch.nn as nn
import torchvision.transforms as transforms
import torch.optim as optim
import torchvision.datasets as datasets
import imageio
import numpy as np
import matplotlib

# %%
from torchvision.utils import make_grid, save_image # save pytorch image and easy maaner without much hassle
from torch.utils.data import DataLoader
from matplotlib import pyplot as plt
from tqdm import tqdm

# %%
matplotlib.style.use('ggplot')

# %%
# learning parameters
batch_size = 512  # 28 * 28
epochs = 200
sample_size = 64 # fixed sample size
nz = 128 # latent vector size
k = 1 # number of steps to apply to the discriminator
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
transform = transforms.Compose([
                                transforms.ToTensor(),
                                transforms.Normalize((0.5,),(0.5,)),
]) # image 변환 
to_pil_image = transforms.ToPILImage() # gif를 생성하고 싶을때 사용 -> epochs 동안 생성 되는 이미지들을 gif로 변환시킴

# %%
train_data = datasets.MNIST(
    root='../input/data',
    train=True,
    download=True,
    transform=transform
)
train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True)

# %%
class Generator(nn.Module):
    def __init__(self, nz): # nz = number of input features
        super(Generator, self).__init__()
        self.nz = nz
        self.main = nn.Sequential( # 순차적으로 시작
            nn.Linear(self.nz, 256), # Linear(입력차원, 출력 차원)
            nn.LeakyReLU(0.2),
            nn.Linear(256, 512),
            nn.LeakyReLU(0.2),
            nn.Linear(512, 1024),
            nn.LeakyReLU(0.2),
            nn.Linear(1024, 784),
            nn.Tanh(),
        )
    def forward(self, x):
        return self.main(x).view(-1, 1, 28, 28)

# %%
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.n_input = 784
        self.main = nn.Sequential(
            nn.Linear(self.n_input, 1024),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(1024, 512),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3),
            nn.Linear(256, 1),
            nn.Sigmoid(),
        )
    def forward(self, x):
        x = x.view(-1, 784)
        return self.main(x)

# %%
generator = Generator(nz).to(device)
discriminator = Discriminator().to(device)
print('##### GENERATOR #####')
print(generator)
print('######################')
print('\n##### DISCRIMINATOR #####')
print(discriminator)
print('######################')
# Out:
# ##### GENERATOR #####
# Generator(
#   (main): Sequential(
#     (0): Linear(in_features=128, out_features=256, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Linear(in_features=256, out_features=512, bias=True)
#     (3): LeakyReLU(negative_slope=0.2)
#     (4): Linear(in_features=512, out_features=1024, bias=True)
#     (5): LeakyReLU(negative_slope=0.2)
#     (6): Linear(in_features=1024, out_features=784, bias=True)
#     (7): Tanh()
#   )
# )
# ######################
#
# ##### DISCRIMINATOR #####
# Discriminator(
#   (main): Sequential(
#     (0): Linear(in_features=784, out_features=1024, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=512, out_features=256, bias=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Dropout(p=0.3, inplace=False)
#     (9): Linear(in_features=256, out_features=1, bias=True)
#     (10): Sigmoid()
#   )
# )
# ######################

# %%
# optimizers
optim_g = optim.Adam(generator.parameters(), lr=0.0002)
optim_d = optim.Adam(discriminator.parameters(), lr=0.0002)

# %%
# loss function
criterion = nn.BCELoss()

# %%
losses_g = [] # to store generator loss after each epoch
losses_d = [] # to store discriminator loss after each epoch
images = [] # to store images generatd by the generator

# %%
# to create real labels (1s)
def label_real(size):
    data = torch.ones(size, 1)
    return data.to(device)
# to create fake labels (0s)
def label_fake(size):
    data = torch.zeros(size, 1)
    return data.to(device)

# %%
# function to create the noise vector
def create_noise(sample_size, nz):
    return torch.randn(sample_size, nz).to(device)

# %%
# to save the images generated by the generator
def save_generator_image(image, path):
    save_image(image, path)

# %%
# function to train the discriminator network
def train_discriminator(optimizer, data_real, data_fake):
    b_size = data_real.size(0)
    real_label = label_real(b_size)
    fake_label = label_fake(b_size)
    optimizer.zero_grad()
    output_real = discriminator(data_real)
    loss_real = criterion(output_real, real_label)
    output_fake = discriminator(data_fake)
    loss_fake = criterion(output_fake, fake_label)
    loss_real.backward()
    loss_fake.backward()
    optimizer.step()
    return loss_real + loss_fake

# %%
# function to train the generator network
def train_generator(optimizer, data_fake):
    b_size = data_fake.size(0)
    real_label = label_real(b_size)
    optimizer.zero_grad()
    output = discriminator(data_fake)
    loss = criterion(output, real_label)
    loss.backward()
    optimizer.step()
    return loss

# %%
# create the noise vector
noise = create_noise(sample_size, nz)

# %%
generator.train()
discriminator.train()
# Out:
# Discriminator(
#   (main): Sequential(
#     (0): Linear(in_features=784, out_features=1024, bias=True)
#     (1): LeakyReLU(negative_slope=0.2)
#     (2): Dropout(p=0.3, inplace=False)
#     (3): Linear(in_features=1024, out_features=512, bias=True)
#     (4): LeakyReLU(negative_slope=0.2)
#     (5): Dropout(p=0.3, inplace=False)
#     (6): Linear(in_features=512, out_features=256, bias=True)
#     (7): LeakyReLU(negative_slope=0.2)
#     (8): Dropout(p=0.3, inplace=False)
#     (9): Linear(in_features=256, out_features=1, bias=True)
#     (10): Sigmoid()
#   )
# )

# %%
for epoch in range(epochs):
    loss_g = 0.0
    loss_d = 0.0
    for bi, data in tqdm(enumerate(train_loader), total=int(len(train_data)/train_loader.batch_size)):
        image, _ = data
        image = image.to(device)
        b_size = len(image)
        # run the discriminator for k number of steps
        for step in range(k):
            data_fake = generator(create_noise(b_size, nz)).detach()
            data_real = image
            # train the discriminator network
            loss_d += train_discriminator(optim_d, data_real, data_fake)
        data_fake = generator(create_noise(b_size, nz))
        # train the generator network
        loss_g += train_generator(optim_g, data_fake)
    # create the final fake image for the epoch
    generated_img = generator(noise).cpu().detach()
    # make the images as grid
    generated_img = make_grid(generated_img)
    # save the generated torch tensor models to disk
    save_generator_image(generated_img, f"../outputs/gen_img{epoch}.png")
    images.append(generated_img)
    epoch_loss_g = loss_g / bi # total generator loss for the epoch
    epoch_loss_d = loss_d / bi # total discriminator loss for the epoch
    losses_g.append(epoch_loss_g)
    losses_d.append(epoch_loss_d)
    
    print(f"Epoch {epoch} of {epochs}")
    print(f"Generator loss: {epoch_loss_g:.8f}, Discriminator loss: {epoch_loss_d:.8f}")
# Out:
# Discriminator loss: 1.14767790
# 118it [00:22,  5.17it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 78 of 200
# Generator loss: 1.14532578, Discriminator loss: 1.15131509
# 118it [00:22,  5.18it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 79 of 200
# Generator loss: 1.13417709, Discriminator loss: 1.16421163
# 118it [00:23,  5.02it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 80 of 200
# Generator loss: 1.15874135, Discriminator loss: 1.13651812
# 118it [00:27,  4.30it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 81 of 200
# Generator loss: 1.10511684, Discriminator loss: 1.16395676
# 118it [00:22,  5.35it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 82 of 200
# Generator loss: 1.13549006, Discriminator loss: 1.15880477
# 118it [00:22,  5.31it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 83 of 200
# Generator loss: 1.07693267, Discriminator loss: 1.18302202
# 118it [00:22,  5.21it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 84 of 200
# Generator loss: 1.13489354, Discriminator loss: 1.17810357
# 118it [00:21,  5.45it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 85 of 200
# Generator loss: 1.09044540, Discriminator loss: 1.16942728
# 118it [00:22,  5.23it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 86 of 200
# Generator loss: 1.10427678, Discriminator loss: 1.18007982
# 118it [00:22,  5.16it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 87 of 200
# Generator loss: 1.10402095, Discriminator loss: 1.17091811
# 118it [00:25,  4.67it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 88 of 200
# Generator loss: 1.07510364, Discriminator loss: 1.18732321
# 118it [00:24,  4.82it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 89 of 200
# Generator loss: 1.09485006, Discriminator loss: 1.16699934
# 118it [00:21,  5.57it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 90 of 200
# Generator loss: 1.09525418, Discriminator loss: 1.18188536
# 118it [00:22,  5.33it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 91 of 200
# Generator loss: 1.09724343, Discriminator loss: 1.17878079
# 118it [00:23,  5.06it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 92 of 200
# Generator loss: 1.07258582, Discriminator loss: 1.18452537
# 118it [00:22,  5.15it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 93 of 200
# Generator loss: 1.10594249, Discriminator loss: 1.17817307
# 118it [00:22,  5.18it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 94 of 200
# Generator loss: 1.10674250, Discriminator loss: 1.18102884
# 118it [00:24,  4.90it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 95 of 200
# Generator loss: 1.08367646, Discriminator loss: 1.18662763
# 118it [00:23,  5.08it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 96 of 200
# Generator loss: 1.07910335, Discriminator loss: 1.19041216
# 118it [00:24,  4.79it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 97 of 200
# Generator loss: 1.05882061, Discriminator loss: 1.19993830
# 118it [00:23,  4.98it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 98 of 200
# Generator loss: 1.06944358, Discriminator loss: 1.17426085
# 118it [00:23,  5.10it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 99 of 200
# Generator loss: 1.06745923, Discriminator loss: 1.18517649
# 118it [00:23,  4.99it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 100 of 200
# Generator loss: 1.06206548, Discriminator loss: 1.19909763
# 118it [00:23,  4.97it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 101 of 200
# Generator loss: 1.06242979, Discriminator loss: 1.19070101
# 118it [00:23,  5.03it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 102 of 200
# Generator loss: 1.06413352, Discriminator loss: 1.19276690
# 118it [00:23,  4.94it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 103 of 200
# Generator loss: 1.07381511, Discriminator loss: 1.19291306
# 118it [00:23,  5.00it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 104 of 200
# Generator loss: 1.08802330, Discriminator loss: 1.18380904
# 118it [00:23,  4.96it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 105 of 200
# Generator loss: 1.06423569, Discriminator loss: 1.20131838
# 118it [00:23,  4.99it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 106 of 200
# Generator loss: 1.06159019, Discriminator loss: 1.19830298
# 118it [00:24,  4.80it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 107 of 200
# Generator loss: 1.06621659, Discriminator loss: 1.20248711
# 118it [00:23,  4.94it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 108 of 200
# Generator loss: 1.07820427, Discriminator loss: 1.18247533
# 118it [00:25,  4.55it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 109 of 200
# Generator loss: 1.05128622, Discriminator loss: 1.21596658
# 118it [00:23,  5.01it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 110 of 200
# Generator loss: 1.08383322, Discriminator loss: 1.17897296
# 118it [00:29,  4.07it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 111 of 200
# Generator loss: 1.05872011, Discriminator loss: 1.19577634
# 118it [00:25,  4.71it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 112 of 200
# Generator loss: 1.08773232, Discriminator loss: 1.18172479
# 118it [00:24,  4.90it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 113 of 200
# Generator loss: 1.11007035, Discriminator loss: 1.17260087
# 118it [00:23,  5.08it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 114 of 200
# Generator loss: 1.07770681, Discriminator loss: 1.18397903
# 118it [00:23,  4.93it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 115 of 200
# Generator loss: 1.09851348, Discriminator loss: 1.17009354
# 118it [00:24,  4.91it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 116 of 200
# Generator loss: 1.08040547, Discriminator loss: 1.18271410
# 118it [00:26,  4.52it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 117 of 200
# Generator loss: 1.06298184, Discriminator loss: 1.20064771
# 118it [00:24,  4.91it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 118 of 200
# Generator loss: 1.06094623, Discriminator loss: 1.18483877
# 118it [00:24,  4.90it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 119 of 200
# Generator loss: 1.06284237, Discriminator loss: 1.20741725
# 118it [00:24,  4.91it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 120 of 200
# Generator loss: 1.07190251, Discriminator loss: 1.18701434
# 118it [00:23,  4.99it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 121 of 200
# Generator loss: 1.08967352, Discriminator loss: 1.18262243
# 118it [00:26,  4.53it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 122 of 200
# Generator loss: 1.09536099, Discriminator loss: 1.18060756
# 118it [00:24,  4.88it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 123 of 200
# Generator loss: 1.12164557, Discriminator loss: 1.17900968
# 118it [00:24,  4.74it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 124 of 200
# Generator loss: 1.05381548, Discriminator loss: 1.20079017
# 118it [00:25,  4.65it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 125 of 200
# Generator loss: 1.08368075, Discriminator loss: 1.18926668
# 118it [00:25,  4.57it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 126 of 200
# Generator loss: 1.09133887, Discriminator loss: 1.17900157
# 118it [00:29,  4.03it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 127 of 200
# Generator loss: 1.05660439, Discriminator loss: 1.19130063
# 118it [00:28,  4.08it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 128 of 200
# Generator loss: 1.06783319, Discriminator loss: 1.19719982
# 118it [00:26,  4.39it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 129 of 200
# Generator loss: 1.05027640, Discriminator loss: 1.19226229
# 118it [00:26,  4.39it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 130 of 200
# Generator loss: 1.06015325, Discriminator loss: 1.19757855
# 118it [00:29,  3.98it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 131 of 200
# Generator loss: 1.06974471, Discriminator loss: 1.19983780
# 118it [00:28,  4.13it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 132 of 200
# Generator loss: 1.04996789, Discriminator loss: 1.19614196
# 118it [00:24,  4.86it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 133 of 200
# Generator loss: 1.04297149, Discriminator loss: 1.20122993
# 118it [00:24,  4.84it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 134 of 200
# Generator loss: 1.04908299, Discriminator loss: 1.19874501
# 118it [00:24,  4.85it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 135 of 200
# Generator loss: 1.06617856, Discriminator loss: 1.20481110
# 118it [00:25,  4.65it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 136 of 200
# Generator loss: 1.05732846, Discriminator loss: 1.19800055
# 118it [00:30,  3.83it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 137 of 200
# Generator loss: 1.07243860, Discriminator loss: 1.19058979
# 118it [00:31,  3.72it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 138 of 200
# Generator loss: 1.07842696, Discriminator loss: 1.19142425
# 118it [00:31,  3.77it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 139 of 200
# Generator loss: 1.05309367, Discriminator loss: 1.19655371
# 118it [00:26,  4.52it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 140 of 200
# Generator loss: 1.01880360, Discriminator loss: 1.21734464
# 118it [00:25,  4.71it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 141 of 200
# Generator loss: 1.03885508, Discriminator loss: 1.20384073
# 118it [00:24,  4.73it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 142 of 200
# Generator loss: 1.06122184, Discriminator loss: 1.19193614
# 118it [00:29,  3.94it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 143 of 200
# Generator loss: 1.04989481, Discriminator loss: 1.21030319
# 118it [00:23,  4.97it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 144 of 200
# Generator loss: 1.08950865, Discriminator loss: 1.19181979
# 118it [00:24,  4.79it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 145 of 200
# Generator loss: 1.07228804, Discriminator loss: 1.18847883
# 118it [00:24,  4.78it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 146 of 200
# Generator loss: 1.04259098, Discriminator loss: 1.20832634
# 118it [00:24,  4.74it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 147 of 200
# Generator loss: 1.03586698, Discriminator loss: 1.19253659
# 118it [00:30,  3.90it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 148 of 200
# Generator loss: 1.02919555, Discriminator loss: 1.20450139
# 118it [00:29,  4.03it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 149 of 200
# Generator loss: 1.06091285, Discriminator loss: 1.21209979
# 118it [00:25,  4.69it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 150 of 200
# Generator loss: 1.03887725, Discriminator loss: 1.20703232
# 118it [00:26,  4.53it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 151 of 200
# Generator loss: 1.06307638, Discriminator loss: 1.20613062
# 118it [00:28,  4.20it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 152 of 200
# Generator loss: 1.03760636, Discriminator loss: 1.19984353
# 118it [00:28,  4.08it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 153 of 200
# Generator loss: 1.05488491, Discriminator loss: 1.19955122
# 118it [00:26,  4.38it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 154 of 200
# Generator loss: 1.03384614, Discriminator loss: 1.21352530
# 118it [00:27,  4.36it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 155 of 200
# Generator loss: 1.02103484, Discriminator loss: 1.21839428
# 118it [00:24,  4.84it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 156 of 200
# Generator loss: 1.02176380, Discriminator loss: 1.21499741
# 118it [00:23,  4.92it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 157 of 200
# Generator loss: 1.04201603, Discriminator loss: 1.20888340
# 118it [00:23,  4.94it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 158 of 200
# Generator loss: 1.04967868, Discriminator loss: 1.22150397
# 118it [00:24,  4.84it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 159 of 200
# Generator loss: 1.01249385, Discriminator loss: 1.20822835
# 118it [00:24,  4.73it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 160 of 200
# Generator loss: 1.06289911, Discriminator loss: 1.20194149
# 118it [00:24,  4.91it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 161 of 200
# Generator loss: 1.03685260, Discriminator loss: 1.21527410
# 118it [00:23,  5.05it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 162 of 200
# Generator loss: 1.04129028, Discriminator loss: 1.21351659
# 118it [00:25,  4.70it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 163 of 200
# Generator loss: 1.00083101, Discriminator loss: 1.22188127
# 118it [00:24,  4.87it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 164 of 200
# Generator loss: 1.04950476, Discriminator loss: 1.20510256
# 118it [00:28,  4.12it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 165 of 200
# Generator loss: 1.02054274, Discriminator loss: 1.21144962
# 118it [00:29,  4.02it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 166 of 200
# Generator loss: 1.03114498, Discriminator loss: 1.20850003
# 118it [00:24,  4.81it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 167 of 200
# Generator loss: 1.01667607, Discriminator loss: 1.21378303
# 118it [00:24,  4.91it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 168 of 200
# Generator loss: 1.02294111, Discriminator loss: 1.21382189
# 118it [00:23,  4.96it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 169 of 200
# Generator loss: 1.02224171, Discriminator loss: 1.21913660
# 118it [00:24,  4.88it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 170 of 200
# Generator loss: 1.05351579, Discriminator loss: 1.22282219
# 118it [00:24,  4.89it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 171 of 200
# Generator loss: 1.02125275, Discriminator loss: 1.20971310
# 118it [00:26,  4.47it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 172 of 200
# Generator loss: 1.03358150, Discriminator loss: 1.23017955
# 118it [00:25,  4.70it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 173 of 200
# Generator loss: 0.99670684, Discriminator loss: 1.22264636
# 118it [00:25,  4.58it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 174 of 200
# Generator loss: 1.03834367, Discriminator loss: 1.20784783
# 118it [00:25,  4.67it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 175 of 200
# Generator loss: 1.02480412, Discriminator loss: 1.22285557
# 118it [00:25,  4.70it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 176 of 200
# Generator loss: 1.01667953, Discriminator loss: 1.21927309
# 118it [00:25,  4.65it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 177 of 200
# Generator loss: 1.03765845, Discriminator loss: 1.21118879
# 118it [00:25,  4.57it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 178 of 200
# Generator loss: 0.98716640, Discriminator loss: 1.22221422
# 118it [00:25,  4.72it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 179 of 200
# Generator loss: 1.04905593, Discriminator loss: 1.20644152
# 118it [00:28,  4.17it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 180 of 200
# Generator loss: 1.02791500, Discriminator loss: 1.20977211
# 118it [00:30,  3.83it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 181 of 200
# Generator loss: 1.05151820, Discriminator loss: 1.20578849
# 118it [00:26,  4.53it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 182 of 200
# Generator loss: 0.99030221, Discriminator loss: 1.24213874
# 118it [00:25,  4.62it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 183 of 200
# Generator loss: 0.99779969, Discriminator loss: 1.22320604
# 118it [00:24,  4.72it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 184 of 200
# Generator loss: 1.01392460, Discriminator loss: 1.21810520
# 118it [00:25,  4.64it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 185 of 200
# Generator loss: 1.02575755, Discriminator loss: 1.21310508
# 118it [00:26,  4.41it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 186 of 200
# Generator loss: 1.01722300, Discriminator loss: 1.22008443
# 118it [00:25,  4.66it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 187 of 200
# Generator loss: 1.03483212, Discriminator loss: 1.21226716
# 118it [00:28,  4.11it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 188 of 200
# Generator loss: 1.01233542, Discriminator loss: 1.21418035
# 118it [00:30,  3.92it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 189 of 200
# Generator loss: 1.02291787, Discriminator loss: 1.21835554
# 118it [00:25,  4.59it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 190 of 200
# Generator loss: 1.08331037, Discriminator loss: 1.21129906
# 118it [00:23,  4.92it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 191 of 200
# Generator loss: 1.00725448, Discriminator loss: 1.22810960
# 118it [00:27,  4.24it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 192 of 200
# Generator loss: 1.04941595, Discriminator loss: 1.19376242
# 118it [00:24,  4.77it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 193 of 200
# Generator loss: 1.00578368, Discriminator loss: 1.20941544
# 118it [00:26,  4.50it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 194 of 200
# Generator loss: 1.04171872, Discriminator loss: 1.21863377
# 118it [00:25,  4.64it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 195 of 200
# Generator loss: 1.02446318, Discriminator loss: 1.20691884
# 118it [00:24,  4.79it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 196 of 200
# Generator loss: 1.01641476, Discriminator loss: 1.21690023
# 118it [00:25,  4.69it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 197 of 200
# Generator loss: 1.01713943, Discriminator loss: 1.21079683
# 118it [00:25,  4.61it/s]
#   0%|          | 0/117 [00:00<?, ?it/s]Epoch 198 of 200
# Generator loss: 1.01599669, Discriminator loss: 1.21080709
# 118it [00:31,  3.79it/s]                         Epoch 199 of 200
# Generator loss: 1.00115526, Discriminator loss: 1.22929835

# %%
print('DONE TRAINING')
torch.save(generator.state_dict(), '../outputs/generator.pth')
# Out:
# DONE TRAINING

# %%
# save the generated images as GIF file
imgs = [np.array(to_pil_image(img)) for img in images]
imageio.mimsave('../outputs/generator_images.gif', imgs)

# %%
losses_d_cpu = []
losses_g_cpu = []

# %%
for i in range(len(losses_d)):
    losses_d_cpu.append(losses_d[i])
    losses_g_cpu.append(losses_g[i])

# %%
# plot and save the generator and discriminator loss
plt.figure()
plt.plot(losses_g_cpu, label='Generator loss')
plt.plot(losses_d_cpu, label='Discriminator Loss')
plt.legend()
plt.savefig('../outputs/loss.png')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-128-f39edcee0504> in <module>
#       1 # plot and save the generator and discriminator loss
#       2 plt.figure()
# ----> 3 plt.plot(losses_g_cpu, label='Generator loss')
#       4 plt.plot(losses_d_cpu, label='Discriminator Loss')
#       5 plt.legend()
#
# ~\anaconda3\envs\Torch\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2986 @_copy_docstring_and_deprecators(Axes.plot)
#    2987 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2988     return gca().plot(
#    2989         *args, scalex=scalex, scaley=scaley,
#    2990         **({"data": data} if data is not None else {}), **kwargs)
#
# ~\anaconda3\envs\Torch\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1603         """
#    1604         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1605         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1606         for line in lines:
#    1607             self.add_line(line)
#
# ~\anaconda3\envs\Torch\lib\site-packages\matplotlib\axes\_base.py in __call__(self, data, *args, **kwargs)
#     313                 this += args[0],
#     314                 args = args[1:]
# --> 315             yield from self._plot_args(this, kwargs)
#     316
#     317     def get_next_color(self):
#
# ~\anaconda3\envs\Torch\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs, return_kwargs)
#     491             y = _check_1d(xy[1])
#     492         else:
# --> 493             x, y = index_of(xy[-1])
#     494
#     495         if self.axes.xaxis is not None:
#
# ~\anaconda3\envs\Torch\lib\site-packages\matplotlib\cbook\__init__.py in index_of(y)
#    1685         pass
#    1686     try:
# -> 1687         y = _check_1d(y)
#    1688     except (np.VisibleDeprecationWarning, ValueError):
#    1689         # NumPy 1.19 will warn on ragged input, and we can't actually use it.
#
# ~\anaconda3\envs\Torch\lib\site-packages\matplotlib\cbook\__init__.py in _check_1d(x)
#    1337     """Convert scalars to 1D arrays; pass-through arrays as is."""
#    1338     if not hasattr(x, 'shape') or len(x.shape) < 1:
# -> 1339         return np.atleast_1d(x)
#    1340     else:
#    1341         try:
#
# <__array_function__ internals> in atleast_1d(*args, **kwargs)
#
# ~\anaconda3\envs\Torch\lib\site-packages\numpy\core\shape_base.py in atleast_1d(*arys)
#      64     res = []
#      65     for ary in arys:
# ---> 66         ary = asanyarray(ary)
#      67         if ary.ndim == 0:
#      68             result = ary.reshape(1)
#
# ~\anaconda3\envs\Torch\lib\site-packages\numpy\core\_asarray.py in asanyarray(a, dtype, order, like)
#     169         return _asanyarray_with_like(a, dtype=dtype, order=order, like=like)
#     170
# --> 171     return array(a, dtype, copy=False, order=order, subok=True)
#     172
#     173
#
# ~\anaconda3\envs\Torch\lib\site-packages\torch\tensor.py in __array__(self, dtype)
#     619             return handle_torch_function(Tensor.__array__, (self,), self, dtype=dtype)
#     620         if dtype is None:
# --> 621             return self.numpy()
#     622         else:
#     623             return self.numpy().astype(dtype, copy=False)
#
# TypeError: can't convert cuda:0 device type tensor to numpy. Use Tensor.cpu() to copy the tensor to host memory first.
